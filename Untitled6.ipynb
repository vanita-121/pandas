# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("diabetes-dataset.csv")
df.info()
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               2000 non-null   int64
#  1   Glucose                   2000 non-null   int64
#  2   BloodPressure             2000 non-null   int64
#  3   SkinThickness             2000 non-null   int64
#  4   Insulin                   2000 non-null   int64
#  5   BMI                       2000 non-null   float64
#  6   DiabetesPedigreeFunction  2000 non-null   float64
#  7   Age                       2000 non-null   int64
#  8   Outcome                   2000 non-null   int64
# dtypes: float64(2), int64(7)
# memory usage: 140.8 KB
#       Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0               2      138             62             35        0  33.6
# ...

# %%
plt.scatter(df["Pregnancies"],df["Glucose"])

# %%
x=df.iloc[:,0:1]
x
y=df.iloc[:,-1]
y
# Out:
# 0       1
# 1       0
# 2       1
# 3       1
# 4       0
#        ..
# 1995    0
# 1996    1
# 1997    0
# 1998    1
# 1999    0
# Name: Outcome, Length: 2000, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=2)

# %%
x_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 400 entries, 278 to 1674
# Data columns (total 1 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Pregnancies  400 non-null    int64
# dtypes: int64(1)
# memory usage: 6.2 KB

# %%
x_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1600 entries, 333 to 1192
# Data columns (total 1 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Pregnancies  1600 non-null   int64
# dtypes: int64(1)
# memory usage: 25.0 KB

# %%
y_test.info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 400 entries, 278 to 1674
# Series name: Outcome
# Non-Null Count  Dtype
# --------------  -----
# 400 non-null    int64
# dtypes: int64(1)
# memory usage: 6.2 KB

# %%
from sklearn.linear_model import LogisticRegression

# %%
llr=LogisticRegression()

# %%
llr.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_prdct=llr.predict(x_test)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_prdct)
# Out:
# 0.6825

# %%
plt.scatter(df["Pregnancies"],df["Glucose"])
plt.plot(y_test,y_prdct,color="red",label="logistic line")
plt.legend()

# %%
df.head(4)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            2      138             62             35        0  33.6
# 1            0       84             82             31      125  38.2
# 2            0      145              0              0        0  44.2
# 3            0      135             68             42      250  42.3
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.127   47        1
# 1                     0.233   23        0
# 2                     0.630   31        1
# 3                     0.365   24        1

# %%
m=llr.coef_
b=llr.intercept_
s=1/(1+np.exp(-(m*2+b)))
s
# Out:
# array([[0.28599961]])
