# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
zdata=pd.read_csv("house_price_prediction_dataset.csv")
zdata.info()
zdata
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Square Footage/Area      1000 non-null   int64
#  1   Number of Bedrooms       1000 non-null   int64
#  2   Number of Bathrooms      1000 non-null   int64
#  3   Year Built               1000 non-null   int64
#  4   Number of Floors         1000 non-null   int64
#  5   Distance to City Center  1000 non-null   float64
#  6   Age of House             1000 non-null   int64
#  7   House Price              1000 non-null   float64
# dtypes: float64(2), int64(6)
# memory usage: 62.6 KB
#      Square Footage/Area  Number of Bedrooms  Number of Bathrooms  Year Built  \
# 0                   1360                   2                    1        1931
# 1                   4272                   3                    3        1966
# ...

# %%
sns.pairplot(zdata)

# %%
# x=zdata["Square Footage/Area"]
# y=zdata["Number of Bedrooms"]
# plt.scatter(x,y)
# plt.title("This is a house price prediction database",fontsize=15,color="Blue")
# plt.xlabel("Square Footage/Area",fontsize=15,color="Blue")
# plt.ylabel("Number of Bedrooms",fontsize=15,color="Blue")

# %%
x=zdata.iloc[:,0:7]
print("x/n",x)
y=zdata.iloc[:,-1]
print("x/n",y)
# Out:
# x/n      Square Footage/Area  Number of Bedrooms  Number of Bathrooms  Year Built  \
# 0                   1360                   2                    1        1931
# 1                   4272                   3                    3        1966
# 2                   3592                   1                    2        1966
# 3                    966                   1                    2        1927
# 4                   4926                   2                    1        1943
# ..                   ...                 ...                  ...         ...
# 995                 3261                   4                    1        1952
# 996                 3179                   1                    2        2019
# 997                 2606                   4                    2        2015
# 998                 4723                   5                    2        1922
# 999                 3268                   4                    2        2008
#
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=5)

# %%
x_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 800 entries, 40 to 867
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Square Footage/Area      800 non-null    int64
#  1   Number of Bedrooms       800 non-null    int64
#  2   Number of Bathrooms      800 non-null    int64
#  3   Year Built               800 non-null    int64
#  4   Number of Floors         800 non-null    int64
#  5   Distance to City Center  800 non-null    float64
#  6   Age of House             800 non-null    int64
# dtypes: float64(1), int64(6)
# memory usage: 50.0 KB

# %%
x_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 200 entries, 544 to 165
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Square Footage/Area      200 non-null    int64
#  1   Number of Bedrooms       200 non-null    int64
#  2   Number of Bathrooms      200 non-null    int64
#  3   Year Built               200 non-null    int64
#  4   Number of Floors         200 non-null    int64
#  5   Distance to City Center  200 non-null    float64
#  6   Age of House             200 non-null    int64
# dtypes: float64(1), int64(6)
# memory usage: 12.5 KB

# %%
y_test.info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 200 entries, 544 to 165
# Series name: House Price
# Non-Null Count  Dtype
# --------------  -----
# 200 non-null    float64
# dtypes: float64(1)
# memory usage: 3.1 KB

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_prdct=lr.predict(x_test)

# %%
zdata.head(7)
# Out:
#    Square Footage/Area  Number of Bedrooms  Number of Bathrooms  Year Built  \
# 0                 1360                   2                    1        1931
# 1                 4272                   3                    3        1966
# 2                 3592                   1                    2        1966
# 3                  966                   1                    2        1927
# 4                 4926                   2                    1        1943
# 5                 3944                   5                    3        1978
# 6                 3671                   1                    2        1940
#
#    Number of Floors  Distance to City Center  Age of House    House Price
# 0                 1                21.598000            94   18589.261072
# 1                 3                 8.816612            59  216574.894902
# 2                 2                11.232384            59  156828.849255
# ...

# %%
#y=b1x1+b2x2+b3x3+b4x4=b5x5=b6x6=b7x7+bo
bo=lr.intercept_
bo
bm=lr.coef_
bm
b1=bm[0]
b2=bm[1]
b3=bm[2]
b4=bm[3]
b5=bm[4]
b6=bm[5]
b7=bm[6]


print(b1)
print(b2)
print(b3)
print(b4)
print(b5)
print(b6)
print(b7)

y=(b1*1360)+(b2*2)+(b3*1)+(b4*1931)+(b5*1)+(b6*21.598000)+bo#+(b7*94)+bo
y
# y=(b1*23)+(b2*23)+bo
# y
# Out:
# 49.430779255463776
# 11942.872898441194
# 14927.761341480447
# 232.60912258597273
# 15641.747186388158
# -2815.0272740665387
# -232.60912258592543
# np.float64(19582.05427097017)

# %%
# plt.scatter(zdata["Square Footage/Area"],zdata["Number of Bedrooms"])
# plt.plot(x_test,y_prdct,color="red",label="Regression line")
sns.lmplot(
    x="Square Footage/Area",
    y="Number of Bedrooms",
        data=zdata,
            line_kws={"color": "red","linewidth":5,"label":"Regression line","linestyle":"solid"},

 )
plt.title("Relationship Between Square Footage and Number of Bedrooms")
plt.xlabel("Square Footage/Area")
plt.ylabel("Number of Bedrooms")

plt.legend()

plt.show()

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test,y_prdct)
# Out:
# 0.696124649314518

# %%
import joblib

# %%
joblib.dump(lr,"house_price_pridictor.joblib")
# Out:
# ['house_price_pridictor.joblib']
